# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Data/Crop_recommendation.csv")

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
plt.plot(data["N"])

# %%
plt.plot(data["P"])

# %%
plt.plot(data["K"])

# %%
plt.plot(data["temperature"])

# %%
plt.plot(data["humidity"])

# %%
plt.plot(data["ph"])

# %%
plt.plot(data["rainfall"])

# %%
data["label"].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
labels = data["label"].unique()

# %%
labels_cat = []
for label in labels:
    labels_cat.append(data[data["label"]==label]["N"])

# %%
[df[df['Category'] == 'A']['Value'],
                df[df['Category'] == 'B']['Value'],
                df[df['Category'] == 'C']['Value']]

# %%
plt.boxplot(labels_cat)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f939ac519a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f939ac5f970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f939ac513a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f939ac5f8e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f939ab53eb0>,
# ...
#  'means': []}

# %%
data["label"].values
# Out:
# array(['rice', 'rice', 'rice', ..., 'coffee', 'coffee', 'coffee'],
#       dtype=object)

# %%
plt.xticks([i for i in range(1,len(data["label"].values)+1)],data["label"].unique())
plt.violinplot(labels_cat)

# %%
data1 = {'Category': ['A', 'B', 'C', 'A', 'B', 'A', 'C', 'A', 'B', 'B'],
        'Value': [3.2, 2.5, 4.1, 2.8, 3.7, 4.2, 2.9, 3.6, 3.3, 3.8]}
df = pd.DataFrame(data1)

# Create a violin plot of the value by category
plt.violinplot([df[df['Category'] == 'A']['Value'],
                df[df['Category'] == 'B']['Value'],
                df[df['Category'] == 'C']['Value']])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f939d39daf0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f939d39da60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f939d3359a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f939d335df0>}
